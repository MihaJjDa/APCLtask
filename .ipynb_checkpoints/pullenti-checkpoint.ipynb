# %% [markdown]
# Скачиваемая, но подключаемая только напрямую библиотека PullEnti
#
# http://pullenti.ru/DownloadPage.aspx
#
# Там же можно найти (после некоторых усилий) обзорную и подробную документации, а так же ссылку на GitHub с примерами
#
# Для работы PullEnti необходимо скачать и положить в папку рядом с ноутбуком

# %% [markdown]
# Проблема библиотеки заключается в её исходном коде - C#. Код на Python получен автоматической генерацией без всякой постобработки. В силу этого код читать тяжело, причем функции и код взаимодействуют по сложно изучаемым интерфейсам.

# %% [markdown]
# Другой вариант:
#
# ```bash
# $ pip install pullenti-wrapper
# ```
#
# Менее функциональная, но более естественная и простая оболочка библиотеки для Python
#
# https://github.com/pullenti/pullenti-wrapper
#
# Более подробное описание в ноутбуке pullenti-wrapper

# %% [markdown]
# Тем не менее, работать с этой библиотекой возможно. Ниже приведен пример из GitHub
#
# Задание заключается в использовании этой библиотеки для измерения точности, полноты и F-меры (по аналогии с ноутбуком natasha) на некотором корпусе (лучший вариант - Named_Entities_3 из http://labinform.ru/pub/named_entities/descr_ne.htm)

# %%
import typing
from pullenti.unisharp.Utils import Utils
from pullenti.unisharp.Misc import Stopwatch

from pullenti.morph.MorphGender import MorphGender
from pullenti.ner.core.NounPhraseHelper import NounPhraseHelper
from pullenti.ner.keyword.KeywordReferent import KeywordReferent
from pullenti.ner.core.GetTextAttr import GetTextAttr
from pullenti.ner.ReferentToken import ReferentToken
from pullenti.ner.MetaToken import MetaToken
from pullenti.morph.MorphLang import MorphLang
from pullenti.ner.core.NounPhraseParseAttr import NounPhraseParseAttr
from pullenti.ner.ProcessorService import ProcessorService
from pullenti.ner.SourceOfAnalysis import SourceOfAnalysis
from pullenti.ner.core.MiscHelper import MiscHelper
from pullenti.ner.keyword.KeywordAnalyzer import KeywordAnalyzer
from pullenti.ner.Sdk import Sdk

# %%
class Program:
    
    @staticmethod
    def main(args : typing.List[str]) -> None:
        sw = Stopwatch()
        # инициализация - необходимо проводить один раз до обработки текстов
        print("Initializing ... ", end="", flush=True)
        # инициализируются движок и все имеющиеся анализаторы
        Sdk.initialize((MorphLang.RU) | MorphLang.EN)
        sw.stop()
        print("OK (by {0} ms), version {1}".format(sw.elapsedMilliseconds, ProcessorService.getVersion()), flush=True)
        # анализируемый текст
        txt = "Единственным конкурентом «Трансмаша» на этом сомнительном тендере было ООО «Плассер Алека Рейл Сервис», основным владельцем которого является австрийская компания «СТЦ-Холдинг ГМБХ». До конца 2011 г. эта же фирма была совладельцем «Трансмаша» вместе с «Тако» Краснова. Зато совладельцем «Плассера», также до конца 2011 г., был тот самый Карл Контрус, который имеет четверть акций «Трансмаша». "
        print("Text: {0}".format(txt), flush=True)
        # запускаем обработку на пустом процессоре (без анализаторов NER)
        are = ProcessorService.getEmptyProcessor().process(SourceOfAnalysis(txt), None, None)
        print("Noun groups: ", end="", flush=True)
        t = are.first_token
        # перебираем токены
        first_pass2703 = True
        while True:
            if first_pass2703: first_pass2703 = False
            else: t = t.next0_
            if (not (t is not None)): break
            # выделяем именную группу с текущего токена
            npt = NounPhraseHelper.tryParse(t, NounPhraseParseAttr.NO, 0)
            # не получилось
            if (npt is None): 
                continue
            # получилось, выводим в нормализованном виде
            print("[{0}=>{1}] ".format(npt.getSourceText(), npt.getNormalCaseText(None, True, MorphGender.UNDEFINED, False)), end="", flush=True)
            # указатель на последний токен именной группы
            t = npt.end_token
        with ProcessorService.createProcessor() as proc: 
            # анализируем текст
            ar = proc.process(SourceOfAnalysis(txt), None, None)
            # результирующие сущности
            print("\r\n==========================================\r\nEntities: ", flush=True)
            for e0_ in ar.entities: 
                print("{0}: {1}".format(e0_.type_name, str(e0_)), flush=True)
                for s in e0_.slots: 
                    print("   {0}: {1}".format(s.type_name, s.value), flush=True)
            # пример выделения именных групп
            print("\r\n==========================================\r\nNoun groups: ", flush=True)
            t = ar.first_token
            first_pass2704 = True
            while True:
                if first_pass2704: first_pass2704 = False
                else: t = t.next0_
                if (not (t is not None)): break
                # токены с сущностями игнорируем
                if (t.getReferent() is not None): 
                    continue
                # пробуем создать именную группу
                npt = NounPhraseHelper.tryParse(t, NounPhraseParseAttr.ADJECTIVECANBELAST, 0)
                # не получилось
                if (npt is None): 
                    continue
                print(npt, flush=True)
                # указатель перемещаем на последний токен группы
                t = npt.end_token
        with ProcessorService.createSpecificProcessor(KeywordAnalyzer.ANALYZER_NAME) as proc: 
            ar = proc.process(SourceOfAnalysis(txt), None, None)
            print("\r\n==========================================\r\nKeywords1: ", flush=True)
            for e0_ in ar.entities: 
                if (isinstance(e0_, KeywordReferent)): 
                    print(e0_, flush=True)
            print("\r\n==========================================\r\nKeywords2: ", flush=True)
            t = ar.first_token
            first_pass2705 = True
            while True:
                if first_pass2705: first_pass2705 = False
                else: t = t.next0_
                if (not (t is not None)): break
                if (isinstance(t, ReferentToken)): 
                    kw = Utils.asObjectOrNull(t.getReferent(), KeywordReferent)
                    if (kw is None): 
                        continue
                    kwstr = MiscHelper.getTextValueOfMetaToken(Utils.asObjectOrNull(t, ReferentToken), Utils.valToEnum((GetTextAttr.FIRSTNOUNGROUPTONOMINATIVESINGLE) | (GetTextAttr.KEEPREGISTER), GetTextAttr))
                    print("{0} = {1}".format(kwstr, kw), flush=True)
        print("Over!", flush=True)

if __name__ == "__main__":
    Program.main(None)
# Out:
# Initializing ... OK (by 8990.85 ms), version 3.16
# Text: Россия рассчитывает на конструктивное воздействие США на Грузию
#
# 04/08/2008 12:08
#
# МОСКВА, 4 авг - РИА Новости. Россия рассчитывает, что США воздействуют на Тбилиси в связи с обострением ситуации в зоне грузино-осетинского конфликта. Об этом статс-секретарь - заместитель министра иностранных дел России Григорий Карасин заявил в телефонном разговоре с заместителем госсекретаря США Дэниэлом Фридом.
#
# "С российской стороны выражена глубокая озабоченность в связи с новым витком напряженности вокруг Южной Осетии, противозаконными действиями грузинской стороны по наращиванию своих вооруженных сил в регионе, бесконтрольным строительством фортификационных сооружений", - говорится в сообщении.
#
# "Россия уже призвала Тбилиси к ответственной линии и рассчитывает также на конструктивное воздействие со стороны Вашингтона", - сообщил МИД России.
# Noun groups: [Россия=>РОССИЯ] [конструктивное воздействие=>КОНСТРУКТИВНОЕ ВОЗДЕЙСТВИЕ] [Грузию=>ГРУЗИЯ] [МОСКВА=>МОСКВА] [Новости=>НОВОСТЬ] [Россия=>РОССИЯ] [Тбилиси=>ТБИЛИСИ] [связи=>СВЯЗЬ] [обострением=>ОБОСТРЕНИЕ] [ситуации=>СИТУАЦИЯ] [зоне=>ЗОНА] [грузино-осетинского конфликта=>ГРУЗИНО-ОСЕТИНСКИЙ КОНФЛИКТ] [статс-секретарь=>СТАТС-СЕКРЕТАРЬ] [заместитель=>ЗАМЕСТИТЕЛЬ] [министра=>МИНИСТР] [иностранных дел=>ИНОСТРАННОЕ ДЕЛО] [России=>РОССИЯ] [Карасин=>КАРАСИН] [телефонном разговоре=>ТЕЛЕФОННЫЙ РАЗГОВОР] [заместителем=>ЗАМЕСТИТЕЛЬ] [госсекретаря=>ГОССЕКРЕТАРЬ] [Дэниэлом=>ДЭНИЭЛ] [российской стороны=>РОССИЙСКАЯ СТОРОНА] [глубокая озабоченность=>ГЛУБОКАЯ ОЗАБОЧЕННОСТЬ] [связи=>СВЯЗЬ] [новым витком=>НОВЫЙ ВИТОК] [напряженности=>НАПРЯЖЕННОСТЬ] [Южной Осетии=>ЮЖНАЯ ОСЕТИЯ] [противозаконными действиями=>ПРОТИВОЗАКОННОЕ ДЕЙСТВИЕ] [грузинской стороны=>ГРУЗИНСКАЯ СТОРОНА] [наращиванию=>НАРАЩИВАНИЕ] [своих вооруженных сил=>ВООРУЖЕННАЯ СИЛА] [регионе=>РЕГИОН] [бесконтрольным строительством=>БЕСКОНТРОЛЬНОЕ СТРОИТЕЛЬСТВО] [фортификационных сооружений=>ФОРТИФИКАЦИОННОЕ СООРУЖЕНИЕ] [сообщении=>СООБЩЕНИЕ] [Россия=>РОССИЯ] [уже=>УЖ] [Тбилиси=>ТБИЛИСИ] [ответственной линии=>ОТВЕТСТВЕННАЯ ЛИНИЯ] [конструктивное воздействие=>КОНСТРУКТИВНОЕ ВОЗДЕЙСТВИЕ] [стороны=>СТОРОНА] [Вашингтона=>ВАШИНГТОН] [МИД=>МИД] [России=>РОССИЯ]
# ==========================================
# Entities:
# DATE: 2008 год
#    YEAR: 2008
# DATE: август 2008 года
#    MONTH: 8
#    HIGHER: 2008 год
# DATE: 4 августа 2008 года
#    DAY: 4
#    HIGHER: август 2008 года
# DATE: 4 августа 2008 года 12:08
#    HOUR: 12
#    MINUTE: 8
#    HIGHER: 4 августа 2008 года
# DATE: август
#    MONTH: 8
# DATE: 4 августа
#    DAY: 4
#    HIGHER: август
# GEO: Россия
#    ALPHA2: RU
#    NAME: РФ
#    NAME: РОССИЙСКАЯ ФЕДЕРАЦИЯ
#    NAME: РОССИЯ
#    TYPE: государство
# GEO: Сша
#    ALPHA2: US
#    NAME: США
#    NAME: СОЕДИНЕННЫЕ ШТАТЫ
#    NAME: СОЕДИНЕННЫЕ ШТАТЫ АМЕРИКИ
#    TYPE: государство
# GEO: Грузия
#    ALPHA2: GE
#    NAME: ГРУЗИЯ
#    TYPE: государство
# GEO: республика Южная Осетия
#    TYPE: республика
#    NAME: ЮЖНАЯ ОСЕТИЯ
#    NAME: ЮЖНО-ОСЕТИНСКАЯ
#    TYPE: регион
#    NAME: ОСЕТИЯ ЮЖНАЯ
#    NAME: ЮЖНО-ОСЕТИНСКИЙ
#    NAME: ЮЖНО-ОСЕТИНСКОЕ
# GEO: Вашингтон
#    TYPE: штат
#    NAME: ВАШИНГТОН
#    TYPE: город
# GEO: город Москва
#    NAME: МОСКВА
#    TYPE: город
# GEO: город Тбилиси
#    NAME: ТБИЛИСИ
#    TYPE: город
# ORGANIZATION: Риа Новости (Апн)
#    PROFILE: MEDIA
#    NAME: РИА НОВОСТИ
#    NAME: АПН
#    NAME: НОВОСТИ
# ORGANIZATION: Министерство Иностранных Дел (Мид), Россия
#    TYPE: министерство
#    PROFILE: State
#    NAME: МИНИСТЕРСТВО ИНОСТРАННЫХ ДЕЛ
#    NAME: МИД
#    NAME: ВНЕШНЕПОЛИТИЧЕСКОЕ ВЕДОМСТВО
#    GEO: Россия
# PERSONPROPERTY: статс-секретарь
#    NAME: статс-секретарь
# PERSONPROPERTY: министр иностранных дел; Россия
#    REF: Россия
#    NAME: министр иностранных дел
# PERSONPROPERTY: заместитель; министр иностранных дел; Россия
#    NAME: заместитель
#    HIGHER: министр иностранных дел; Россия
# PERSON: Григорий Карасин
#    SEX: MALE
#    LASTNAME: КАРАСИН
#    FIRSTNAME: ГРИГОРИЙ
#    ATTRIBUTE: статс-секретарь
#    ATTRIBUTE: заместитель; министр иностранных дел; Россия
# PERSONPROPERTY: государственный секретарь; Сша
#    REF: Сша
#    NAME: государственный секретарь
# PERSONPROPERTY: заместитель; государственный секретарь; Сша
#    NAME: заместитель
#    HIGHER: государственный секретарь; Сша
# PERSON: Фрид Дэниэл
#    SEX: MALE
#    LASTNAME: ДЭНИЭЛ
#    FIRSTNAME: ФРИД
#    ATTRIBUTE: заместитель; государственный секретарь; Сша
#
# ==========================================
# Noun groups:
# 1 КОНСТРУКТИВНОЕ ВОЗДЕЙСТВИЕ существ. ед.ч. ср.р. винит.
# 1 СВЯЗЬ существ. ед.мн.ч. жен.р. родит.|дател.|винит.|предлож.
# 1 ОБОСТРЕНИЕ существ. ед.ч. ср.р. творит.
# 1 СИТУАЦИЯ существ. ед.мн.ч. жен.р. именит.|родит.|дател.|винит.|предлож.
# 1 ЗОНА существ. ед.ч. жен.р. дател.|предлож.
# 1 ГРУЗИНО-ОСЕТИНСКИЙ КОНФЛИКТ существ. ед.ч. муж.р. родит.
# 1 ТЕЛЕФОННЫЙ РАЗГОВОР существ. ед.ч. муж.р. предлож.
# 1 РОССИЙСКАЯ СТОРОНА существ. ед.ч. жен.р. родит.
# 1 ГЛУБОКАЯ ОЗАБОЧЕННОСТЬ существ. ед.ч. жен.р. именит.|винит.
# 1 СВЯЗЬ существ. ед.мн.ч. жен.р. родит.|дател.|винит.|предлож.
# 1 НОВЫЙ ВИТОК существ. ед.ч. муж.р. творит.
# 1 НАПРЯЖЕННОСТЬ существ. ед.мн.ч. жен.р. именит.|родит.|дател.|винит.|предлож.
# 1 ПРОТИВОЗАКОННЫЕ ДЕЙСТВИЯ существ. мн.ч. ср.р. творит.
# 1 ГРУЗИНСКАЯ СТОРОНА существ. ед.ч. жен.р. родит.
# 1 НАРАЩИВАНИЕ существ. ед.ч. ср.р. дател.
# 1 ВООРУЖЕННЫЕ СИЛЫ существ. мн.ч. жен.р. родит.
# 1 РЕГИОН существ. ед.ч. муж.р. предлож.
# 1 БЕСКОНТРОЛЬНОЕ СТРОИТЕЛЬСТВО существ. ед.ч. ср.р. творит.
# 1 ФОРТИФИКАЦИОННЫЕ СООРУЖЕНИЯ существ. мн.ч. ср.р. родит.
# 1 СООБЩЕНИЕ существ. ед.ч. ср.р. предлож.
# 1 УЖ существ. ед.ч. муж.р. предлож.
# 1 ОТВЕТСТВЕННАЯ ЛИНИЯ существ. ед.ч. жен.р. родит.|дател.|предлож.
# 1 КОНСТРУКТИВНОЕ ВОЗДЕЙСТВИЕ существ. ед.ч. ср.р. винит.
# 1 СТОРОНА существ. ед.мн.ч. жен.р. родит.|винит.
#
# ==========================================
# Keywords1:
# Россия [RU]
# Сша [US]
# Тбилиси [ТБИЛИСИ]
# Карасин Г. [КАРАСИН Г.]
# Дэниэл Ф. [ДЭНИЭЛ Ф.]
# КОНСТРУКТИВНОЕ ВОЗДЕЙСТВИЕ [ВОЗДЕЙСТВИЕ КОНСТРУКЦИЯ]
# НАРАЩИВАНИЕ СВОИХ ВООРУЖЕННЫХ СИЛ [ВООРУЖЕНИЕ НАРОСТ СИЛА]
# Грузия [GE]
# Москва [МОСКВА]
# Риа Новости (Апн) [РИА НОВОСТИ (АПН)]
# ГРУЗИНО-ОСЕТИНСКИЙ КОНФЛИКТ [ГРУЗИНО КОНФЛИКТ ОСЕТИНСКИЙ]
# РАССЧИТЫВАТЬ [РАСЧЕТ]
# статс-секретарь [СТАТС-СЕКРЕТАРЬ]
# заместитель; министр иностранных дел; Россия [ЗАМЕСТИТЕЛЬ; МИНИСТР ИНОСТРАННЫХ ДЕЛ; РОССИЯ]
# заместитель; государственный секретарь; Сша [ЗАМЕСТИТЕЛЬ; ГОСУДАРСТВЕННЫЙ СЕКРЕТАРЬ; США]
# НОВЫЙ ВИТОК НАПРЯЖЕННОСТИ [ВИТИЕ НАПРЯЖЕНИЕ НОВИЗНА]
# Южная Осетия [ЮЖНАЯ ОСЕТИЯ]
# СТОРОНА
# Вашингтон [ВАШИНГТОН]
# ОБОСТРЕНИЕ СИТУАЦИИ [ОБОСТРЕНИЕ СИТУАЦИЯ]
# Министерство Иностранных Дел (Мид) [МИНИСТЕРСТВО ИНОСТРАННЫХ ДЕЛ (МИД)]
# СВЯЗЬ [СВЯЗКА]
# ТЕЛЕФОННЫЙ РАЗГОВОР [РАЗГОВОР ТЕЛЕФОН]
# КОНСТРУКТИВНЫЙ [КОНСТРУКЦИЯ]
# ВОЗДЕЙСТВИЕ
# РОССИЙСКАЯ СТОРОНА [РОССИЯ СТОРОНА]
# ГЛУБОКАЯ ОЗАБОЧЕННОСТЬ [ГЛУБИНА ОЗАБОЧЕННОСТЬ]
# НОВЫЙ ВИТОК [ВИТИЕ НОВИЗНА]
# ПРОТИВОЗАКОННОЕ ДЕЙСТВИЕ [ДЕЙСТВИЕ ПРОТИВОЗАКОН]
# ГРУЗИНСКАЯ СТОРОНА [ГРУЗИНСКИЙ СТОРОНА]
# ВООРУЖЕННАЯ СИЛА [ВООРУЖЕНИЕ СИЛА]
# БЕСКОНТРОЛЬНОЕ СТРОИТЕЛЬСТВО [БЕСКОНТРОЛЬНОСТЬ СТРОЙ]
# ФОРТИФИКАЦИОННОЕ СООРУЖЕНИЕ [СООРУЖЕНИЕ ФОРТИФИКАЦИЯ]
# ОТВЕТСТВЕННАЯ ЛИНИЯ [ЛИНИЯ ОТВЕТСТВЕННОСТЬ]
# ВОЗДЕЙСТВОВАТЬ [ВОЗДЕЙСТВИЕ]
# ОБОСТРЕНИЕ
# СИТУАЦИЯ
# ЗОНА
# ГРУЗИНО
# ОСЕТИНСКИЙ
# КОНФЛИКТ
# ЗАЯВИТЬ [ЗАЯВЛЕНИЕ]
# ТЕЛЕФОННЫЙ [ТЕЛЕФОН]
# РАЗГОВОР
# РОССИЙСКИЙ [РОССИЯ]
# ВЫРАЗИТЬ [ВЫРАЖЕНИЕ]
# ГЛУБОКИЙ [ГЛУБИНА]
# ОЗАБОЧЕННОСТЬ
# НОВЫЙ [НОВИЗНА]
# ВИТОК [ВИТИЕ]
# НАПРЯЖЕННОСТЬ [НАПРЯЖЕНИЕ]
# ПРОТИВОЗАКОННЫЙ [ПРОТИВОЗАКОН]
# ДЕЙСТВИЕ
# ГРУЗИНСКИЙ
# НАРАЩИВАНИЕ [НАРОСТ]
# ВООРУЖЕННЫЙ [ВООРУЖЕНИЕ]
# СИЛА
# РЕГИОН
# БЕСКОНТРОЛЬНЫЙ [БЕСКОНТРОЛЬНОСТЬ]
# СТРОИТЕЛЬСТВО [СТРОЙ]
# ФОРТИФИКАЦИОННЫЙ [ФОРТИФИКАЦИЯ]
# СООРУЖЕНИЕ
# ГОВОРИТЬ [ГОВОР]
# СООБЩЕНИЕ
# УЗКИЙ [УЗОСТЬ]
# ПРИЗВАТЬ [ПРИЗВАНИЕ]
# ОТВЕТСТВЕННЫЙ [ОТВЕТСТВЕННОСТЬ]
# ЛИНИЯ
# СООБЩИТЬ [СООБЩЕНИЕ]
# Россия рассчитывает на конструктивное воздействие США на Грузию Россия рассчитывает, что США воздействуют на Тбилиси в связи с обострением ситуации в зоне грузино-осетинского конфликта.
#
# ==========================================
# Keywords2:
# Россия = Россия [RU]
# рассчитывает = РАССЧИТЫВАТЬ [РАСЧЕТ]
# конструктивное воздействие = КОНСТРУКТИВНОЕ ВОЗДЕЙСТВИЕ [ВОЗДЕЙСТВИЕ КОНСТРУКЦИЯ]
# США = Сша [US]
# Грузия = Грузия [GE]
# МОСКВА = Москва [МОСКВА]
# РИА Новости = Риа Новости (Апн) [РИА НОВОСТИ (АПН)]
# Россия = Россия [RU]
# рассчитывает = РАССЧИТЫВАТЬ [РАСЧЕТ]
# США = Сша [US]
# воздействуют = ВОЗДЕЙСТВОВАТЬ [ВОЗДЕЙСТВИЕ]
# Тбилиси = Тбилиси [ТБИЛИСИ]
# связь = СВЯЗЬ [СВЯЗКА]
# обострение ситуации = ОБОСТРЕНИЕ СИТУАЦИИ [ОБОСТРЕНИЕ СИТУАЦИЯ]
# зона = ЗОНА
# грузино-осетинского конфликта = ГРУЗИНО-ОСЕТИНСКИЙ КОНФЛИКТ [ГРУЗИНО КОНФЛИКТ ОСЕТИНСКИЙ]
# статс-секретарь - заместитель министра иностранных дел России Григорий Карасин = Карасин Г. [КАРАСИН Г.]
# заявил = ЗАЯВИТЬ [ЗАЯВЛЕНИЕ]
# телефонный разговор = ТЕЛЕФОННЫЙ РАЗГОВОР [РАЗГОВОР ТЕЛЕФОН]
# заместитель госсекретаря США Дэниэлом Фридом = Дэниэл Ф. [ДЭНИЭЛ Ф.]
# российская сторона = РОССИЙСКАЯ СТОРОНА [РОССИЯ СТОРОНА]
# выражена = ВЫРАЗИТЬ [ВЫРАЖЕНИЕ]
# глубокая озабоченность = ГЛУБОКАЯ ОЗАБОЧЕННОСТЬ [ГЛУБИНА ОЗАБОЧЕННОСТЬ]
# связь = СВЯЗЬ [СВЯЗКА]
# новый виток напряженности = НОВЫЙ ВИТОК НАПРЯЖЕННОСТИ [ВИТИЕ НАПРЯЖЕНИЕ НОВИЗНА]
# Южная Осетия = Южная Осетия [ЮЖНАЯ ОСЕТИЯ]
# противозаконное действие = ПРОТИВОЗАКОННОЕ ДЕЙСТВИЕ [ДЕЙСТВИЕ ПРОТИВОЗАКОН]
# грузинская сторона = ГРУЗИНСКАЯ СТОРОНА [ГРУЗИНСКИЙ СТОРОНА]
# наращивание своих вооруженных сил = НАРАЩИВАНИЕ СВОИХ ВООРУЖЕННЫХ СИЛ [ВООРУЖЕНИЕ НАРОСТ СИЛА]
# регион = РЕГИОН
# бесконтрольное строительство = БЕСКОНТРОЛЬНОЕ СТРОИТЕЛЬСТВО [БЕСКОНТРОЛЬНОСТЬ СТРОЙ]
# фортификационное сооружение = ФОРТИФИКАЦИОННОЕ СООРУЖЕНИЕ [СООРУЖЕНИЕ ФОРТИФИКАЦИЯ]
# говорится = ГОВОРИТЬ [ГОВОР]
# сообщение = СООБЩЕНИЕ
# Россия = Россия [RU]
# уж = УЗКИЙ [УЗОСТЬ]
# призвала = ПРИЗВАТЬ [ПРИЗВАНИЕ]
# Тбилиси = Тбилиси [ТБИЛИСИ]
# ответственная линия = ОТВЕТСТВЕННАЯ ЛИНИЯ [ЛИНИЯ ОТВЕТСТВЕННОСТЬ]
# рассчитывает = РАССЧИТЫВАТЬ [РАСЧЕТ]
# конструктивное воздействие = КОНСТРУКТИВНОЕ ВОЗДЕЙСТВИЕ [ВОЗДЕЙСТВИЕ КОНСТРУКЦИЯ]
# сторона = СТОРОНА
# Вашингтон = Вашингтон [ВАШИНГТОН]
# сообщил = СООБЩИТЬ [СООБЩЕНИЕ]
# МИД России = Министерство Иностранных Дел (Мид) [МИНИСТЕРСТВО ИНОСТРАННЫХ ДЕЛ (МИД)]
# Over!
